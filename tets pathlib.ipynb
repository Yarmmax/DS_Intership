# %%
import os
import pandas as pd
from pathlib import Path

# %% [markdown]
# Test pathlib

# %%
# %%time

# set the data path
train_test_data_path = Path('C:\Repository\DS-Intership-data') / 'train_test_data'
print(type(path))

# initiate dict for data
data = {}

# load data to dict
for file_path in train_test_data_path.iterdir():
    if file_path.is_file():
        data[file_path.stem] = pd.read_csv(file_path, index_col=0)
        print(file_path.stem)
# Out:
# <class 'pathlib.WindowsPath'>
# submission_example
# test_data
# train_data
# CPU times: total: 24.6 s
# Wall time: 26.1 s

# %%
data['train_data']
# Out:
#           date_block_num  shop_id  item_id  item_category_id  item_cnt_month  \
# 0                      0        2    22154                37             0.0
# 1                      0        3    22154                37             0.0
# 2                      0        4    22154                37             0.0
# 3                      0        6    22154                37             1.0
# 4                      0        7    22154                37             1.0
# ...                  ...      ...      ...               ...             ...
# 11101369              33       55     7640                64             0.0
# 11101370              33       56     7640                64             0.0
# 11101371              33       57     7640                64             0.0
# 11101372              33       58     7640                64             0.0
# 11101373              33       59     7640                64             0.0
#
#           type_code  subtype_code  shop_city  shop_category  name2  ...  \
# 0                 8             1          0              8      5  ...
# 1                 8             1          1              6      5  ...
# 2                 8             1          2              8      5  ...
# 3                 8             1          4              1      5  ...
# 4                 8             1          4              7      5  ...
# ...             ...           ...        ...            ...    ...  ...
# 11101369         11            43         27             11      5  ...
# 11101370         11            43         28              7      5  ...
# 11101371         11            43         29              4      5  ...
# 11101372         11            43         29              8      5  ...
# 11101373         11            43         30              8      5  ...
#
#           avg_by_month_shop_item_cnt_lag_2  avg_by_month_shop_item_cnt_lag_3  \
# 0                                      NaN                               NaN
# 1                                      NaN                               NaN
# 2                                      NaN                               NaN
# 3                                      NaN                               NaN
# 4                                      NaN                               NaN
# ...                                    ...                               ...
# 11101369                               NaN                               NaN
# 11101370                               NaN                               NaN
# 11101371                               NaN                               NaN
# 11101372                               NaN                               NaN
# 11101373                               NaN                               NaN
#
#           avg_by_month_city_item_cnt_lag_1  avg_by_month_cat_item_cnt_lag_1  \
# 0                                      NaN                              NaN
# 1                                      NaN                              NaN
# 2                                      NaN                              NaN
# 3                                      NaN                              NaN
# 4                                      NaN                              NaN
# ...                                    ...                              ...
# 11101369                               NaN                              NaN
# 11101370                               NaN                              NaN
# 11101371                               NaN                              NaN
# 11101372                               NaN                              NaN
# 11101373                               NaN                              NaN
#
#           delta_price_lag  category_cluster_id  item_price_cluster_id  \
# 0                     0.0                    4                      0
# 1                     0.0                    4                      0
# 2                     0.0                    4                      0
# 3                     0.0                    4                      0
# 4                     0.0                    4                      0
# ...                   ...                  ...                    ...
# 11101369              0.0                    4                      3
# 11101370              0.0                    4                      3
# 11101371              0.0                    4                      3
# 11101372              0.0                    4                      3
# 11101373              0.0                    4                      3
#
#           cluster_id  item_shop_first_sale  item_first_sale
# 0                  3                     0                0
# 1                  3                     0                0
# 2                  3                     0                0
# 3                  0                     0                0
# 4                  0                     0                0
# ...              ...                   ...              ...
# 11101369           3                     0                0
# 11101370           0                     0                0
# 11101371           4                     0                0
# 11101372           0                     0                0
# 11101373           3                     0                0
#
# [10902924 rows x 33 columns]
